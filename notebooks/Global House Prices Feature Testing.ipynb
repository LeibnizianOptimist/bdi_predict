# %% [markdown]
# # Feature Selection for log_diff_model (Multivariate Model)

# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras import Sequential
from bdi_predict.ml_logic.sequence_gen import WindowGenerator
from tensorflow.keras import layers
from sklearn.model_selection import TimeSeriesSplit
from tensorflow.keras.preprocessing.sequence import TimeseriesGenerator
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import StandardScaler
from tensorflow.keras.optimizers import RMSprop
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.optimizers.schedules import ExponentialDecay
from tensorflow.keras.callbacks import EarlyStopping

# %%
bdi = pd.read_csv("../raw_data/data/BDI/log_diff_BDI_daily.csv")
bdi.head(2)
# Out:
#    Unnamed: 0        Date   Price  abs_price  log_price  log_diff
# 0           0  1995-01-03  1964.0        NaN   3.293141       NaN
# 1           1  1995-01-04  1961.0       -3.0   3.292478 -0.000664

# %%
bdi["Date"] = pd.to_datetime(bdi["Date"])
bdi.set_index("Date", inplace=True)
bdi= bdi[bdi.index != "1995-01-03"]
bdi.drop(columns="Unnamed: 0", inplace=True)
bdi.head(2)
# Out:
#              Price  abs_price  log_price  log_diff
# Date
# 1995-01-04  1961.0       -3.0   3.292478 -0.000664
# 1995-01-05  1967.0        6.0   3.293804  0.001327

# %%
feat = pd.read_csv("../raw_data/data/merged_features.csv")
feat["Date"] = pd.to_datetime(feat["Date"])
feat.set_index("Date", inplace=True)
feat.drop(columns="Unnamed: 0", inplace=True)
feat = feat[["equally weighted"]]
feat.rename(columns={"equally weighted":"GHP"}, inplace=True)
GHP=feat
GHP
# Out:
#                    GHP
# Date
# 1995-01-03  100.117367
# 1995-01-04  100.117367
# 1995-01-05  100.117367
# 1995-01-06  100.117367
# 1995-01-09  100.117367
# ...                ...
# 2022-11-08  107.030433
# 2022-11-09  106.747531
# 2022-11-10  106.464629
# 2022-11-11  106.181727
# 2022-11-14  105.898825
#
# [7365 rows x 1 columns]

# %%
df = pd.merge(bdi, GHP, on="Date", how="inner")
#df.drop(columns="Price_y", inplace=True)

# %%
df.head(3)
# Out:
#              Price  abs_price  log_price  log_diff         GHP
# Date
# 1995-01-04  1961.0       -3.0   3.292478 -0.000664  100.117367
# 1995-01-05  1967.0        6.0   3.293804  0.001327  100.117367
# 1995-01-06  1983.0       16.0   3.297323  0.003518  100.117367

# %% [markdown]
# # Data Cleaning

# %% [markdown]
# ## Holdout Method (manual, chronological)

# %%
input_length = len(df)

# %%
def train_test_split(df:pd.DataFrame,
                     train_test_ratio: float,
                     input_length: int) -> tuple:
    '''
    Returns a train dataframe and a test dataframe (df_train, df_test)
    from which one can sample (X,y) sequences using TimeseriesGenerator.
    df_train should contain all the timesteps until round(train_test_ratio * len(fold))   
    '''
    
    # TRAIN SET

    last_train_idx = round(train_test_ratio * len(df))
    df_train = df.iloc[0:last_train_idx, :]

    # TEST SET
 
    first_test_idx = last_train_idx - input_length
    df_test = df.iloc[first_test_idx:, :]

    return (df_train, df_test)

# %%
df_train, df_test = train_test_split(df=df, train_test_ratio=0.8, input_length=input_length)

# %%
X_train = df_train[["Price","GHP"]]
y_train = df_train["log_diff"]

X_test  = df_test[["Price","GHP"]]
y_test = df_test["log_diff"]

# %%
#Feature Scaling

scaler_X = MinMaxScaler()

X_train_scaled = scaler_X.fit_transform(X_train)
X_test_scaled = scaler_X.fit_transform(X_test)

# %%
generator = TimeseriesGenerator(X_train_scaled, y_train, length=20, batch_size=8, sampling_rate=1, stride=1)

# %%
len(generator)
# Out:
# 704

# %%
generator_val = TimeseriesGenerator(X_test_scaled, y_test, length=20, batch_size=8, sampling_rate=1, stride=1)

# %%
for X, y in generator:
    print(X.shape, y.shape)
    print(X[0], y[0])
    #listy = [float(X[0][i]) for i in range(len(X[0]))]
    #print(listy)
    break
# Out:
# (8, 20, 2) (8,)
# [[0.14519214 0.00564203]
#  [0.14571379 0.00564203]
#  [0.14710485 0.00564203]
#  [0.14806121 0.00564203]
#  [0.14988698 0.00564203]
#  [0.15023474 0.00564203]
#  [0.15188663 0.00564203]
#  [0.15379934 0.00564203]
#  [0.15440793 0.00564203]
#  [0.15475569 0.00564203]
#  [0.15475569 0.00564203]
#  [0.15466875 0.00564203]
#  [0.1537124  0.00564203]
#  [0.15240828 0.00564203]
#  [0.15136498 0.00564203]
#  [0.1501478  0.00564203]
#  [0.14823509 0.00564203]
#  [0.14710485 0.00564203]
#  [0.1465832  0.00564203]
#  [0.14623544 0.00564203]] -0.0015435717560743

# %% [markdown]
# # The Model

# %%
# Learning Rate Scheduler: 

lr_schedule = ExponentialDecay(
    initial_learning_rate=1e-3,
    decay_steps=10000,
    decay_rate=0.9)

# %%
#Optimizers

rmsprop = RMSprop(learning_rate=lr_schedule) #or 0.001 for inital test
adam = Adam(learning_rate=lr_schedule)

# %%
#Early Stopping Criterion:

es = EarlyStopping(monitor="val_mae", patience=100, restore_best_weights=True)

# %%
#Initializing and compiling model:

def init_model():
    
    model = Sequential()

    #LSTM layers
    model.add(layers.LSTM(60, activation="tanh", input_shape=(20,2), return_sequences=False))

    #Dense layers
    model.add(layers.Dense(100, activation="relu"))
    model.add(layers.Dense(1, activation="linear"))

    #compiling model
    model.compile(loss="mse", optimizer=rmsprop, metrics="mae")
    
    return model

# %% [markdown]
# # Training and Testing

# %%
#Instantiating model

model = init_model()

# %%
#Model layers & params overview:
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_1 (LSTM)               (None, 60)                15120
#
#  dense_2 (Dense)             (None, 100)               6100
#
#  dense_3 (Dense)             (None, 1)                 101
#
# =================================================================
# Total params: 21,321
# Trainable params: 21,321
# Non-trainable params: 0
# _________________________________________________________________

# %%
#TRAINING THE MODEL:

history = model.fit(
    generator, epochs=1000, validation_data=generator_val, shuffle=True, callbacks=es
)
# Out:
# Epoch 1/1000
# 704/704 [==============================] - 3s 3ms/step - loss: 1.8795e-04 - mae: 0.0095 - val_loss: 1.0413e-04 - val_mae: 0.0077
# Epoch 2/1000
# 704/704 [==============================] - 2s 2ms/step - loss: 7.8000e-05 - mae: 0.0062 - val_loss: 1.0229e-04 - val_mae: 0.0076
# Epoch 3/1000
# 704/704 [==============================] - 2s 2ms/step - loss: 6.9228e-05 - mae: 0.0057 - val_loss: 1.1758e-04 - val_mae: 0.0083
# Epoch 4/1000
# 704/704 [==============================] - 2s 2ms/step - loss: 6.2413e-05 - mae: 0.0054 - val_loss: 1.0582e-04 - val_mae: 0.0078
# Epoch 5/1000
# 704/704 [==============================] - 2s 2ms/step - loss: 5.9532e-05 - mae: 0.0053 - val_loss: 1.0399e-04 - val_mae: 0.0077
# Epoch 6/1000
# 704/704 [==============================] - 2s 2ms/step - loss: 5.9745e-05 - mae: 0.0053 - val_loss: 1.0328e-04 - val_mae: 0.0077
# Epoch 7/1000
# 704/704 [==============================] - 2s 2ms/step - loss: 5.8781e-05 - mae: 0.0052 - val_loss: 1.0279e-04 - val_mae: 0.0076
# Epoch 8/1000
# 704/704 [==============================] - 2s 2ms/step - loss: 5.8166e-05 - mae: 0.0052 - val_loss: 1.1347e-04 - val_mae: 0.0080
# Epoch 9/1000
# 704/704 [==============================] - 2s 2ms/step - loss: 5.7364e-05 - mae: 0.0052 - val_loss: 1.0300e-04 - val_mae: 0.0077
# Epoch 10/1000
# 704/704 [==============================] - 2s 2ms/step - loss: 5.7742e-05 - mae: 0.0052 - val_loss: 1.0869e-04 - val_mae: 0.0078
# Epoch 11/1000
# 704/704 [==============================] - 2s 2ms/step - loss: 5.8218e-05 - mae: 0.0052 - val_loss: 1.0473e-04 - val_mae: 0.0078
# Epoch 12/1000
# 704/704 [==============================] - 2s 2ms/step - loss: 5.8274e-05 - mae: 0.0052 - val_loss: 1.0313e-04 - val_mae: 0.0076
# Epoch 13/1000
# 704/704 [==============================] - 2s 2ms/step - loss: 5.8412e-05 - mae: 0.0052 - val_loss: 1.0200e-04 - val_mae: 0.0076
# Epoch 14/1000
# 704/704 [==============================] - 2s 2ms/step - loss: 5.7760e-05 - mae: 0.0052 - val_loss: 1.0199e-04 - val_mae: 0.0076
# Epoch 15/1000
# 704/704 [==============================] - 2s 2ms/step - loss: 5.8382e-05 - mae: 0.0051 - val_loss: 1.1001e-04 - val_mae: 0.0081
# Epoch 16/1000
# 704/704 [==============================] - 2s 2ms/step - loss: 5.8414e-05 - mae: 0.0052 - val_loss: 1.0217e-04 - val_mae: 0.0076
# Epoch 17/1000
# 704/704 [==============================] - 2s 2ms/step - loss: 5.8056e-05 - mae: 0.0052 - val_loss: 1.0560e-04 - val_mae: 0.0079
# Epoch 18/1000
# 704/704 [==============================] - 2s 2ms/step - loss: 5.8613e-05 - mae: 0.0052 - val_loss: 1.0351e-04 - val_mae: 0.0078
# Epoch 19/1000
# 704/704 [==============================] - 2s 2ms/step - loss: 5.8277e-05 - mae: 0.0052 - val_loss: 1.0223e-04 - val_mae: 0.0076
# Epoch 20/1000
# 704/704 [==============================] - 2s 3ms/step - loss: 5.8845e-05 - mae: 0.0052 - val_loss: 1.0352e-04 - val_mae: 0.0076
# Epoch 21/1000
# 704/704 [==============================] - 2s 2ms/step - loss: 5.8151e-05 - mae: 0.0052 - val_loss: 1.0472e-04 - val_mae: 0.0078
# Epoch 22/1000
# 704/704 [==============================] - 2s 2ms/step - loss: 5.8032e-05 - mae: 0.0052 - val_loss: 1.0274e-04 - val_mae: 0.0077
# Epoch 23/1000
# 704/704 [==============================] - 2s 2ms/step - loss: 5.7847e-05 - mae: 0.0052 - val_loss: 1.1684e-04 - val_mae: 0.0084
# Epoch 24/1000
# 704/704 [==============================] - 2s 2ms/step - loss: 5.7902e-05 - mae: 0.0052 - val_loss: 1.0208e-04 - val_mae: 0.0077
# Epoch 25/1000
# 704/704 [==============================] - 2s 2ms/step - loss: 5.8078e-05 - mae: 0.0051 - val_loss: 1.0622e-04 - val_mae: 0.0077
# Epoch 26/1000
# 704/704 [==============================] - 2s 2ms/step - loss: 5.7857e-05 - mae: 0.0052 - val_loss: 1.0226e-04 - val_mae: 0.0077
# Epoch 27/1000
# 704/704 [==============================] - 2s 2ms/step - loss: 5.8021e-05 - mae: 0.0052 - val_loss: 1.0202e-04 - val_mae: 0.0076
# Epoch 28/1000
# 704/704 [==============================] - 2s 2ms/step - loss: 5.7555e-05 - mae: 0.0051 - val_loss: 1.0334e-04 - val_mae: 0.0077
# Epoch 29/1000
# 704/704 [==============================] - 2s 2ms/step - loss: 5.8472e-05 - mae: 0.0052 - val_loss: 1.0466e-04 - val_mae: 0.0078
# Epoch 30/1000
# 704/704 [==============================] - 2s 2ms/step - loss: 5.7729e-05 - mae: 0.0051 - val_loss: 1.0326e-04 - val_mae: 0.0076
# Epoch 31/1000
# 704/704 [==============================] - 2s 2ms/step - loss: 5.7984e-05 - mae: 0.0052 - val_loss: 1.0259e-04 - val_mae: 0.0077
# Epoch 32/1000
# 704/704 [==============================] - 2s 2ms/step - loss: 5.6925e-05 - mae: 0.0051 - val_loss: 1.0371e-04 - val_mae: 0.0078
# Epoch 33/1000
# 704/704 [==============================] - 2s 2ms/step - loss: 5.7986e-05 - mae: 0.0052 - val_loss: 1.0239e-04 - val_mae: 0.0076
# Epoch 34/1000
# 704/704 [==============================] - 2s 2ms/step - loss: 5.7898e-05 - mae: 0.0052 - val_loss: 1.0219e-04 - val_mae: 0.0077
# Epoch 35/1000
# 704/704 [==============================] - 2s 2ms/step - loss: 5.8423e-05 - mae: 0.0051 - val_loss: 1.0208e-04 - val_mae: 0.0077
# Epoch 36/1000
# 704/704 [==============================] - 2s 2ms/step - loss: 5.7522e-05 - mae: 0.0052 - val_loss: 1.0552e-04 - val_mae: 0.0077
# Epoch 37/1000
# 704/704 [==============================] - 2s 2ms/step - loss: 5.7653e-05 - mae: 0.0051 - val_loss: 1.0278e-04 - val_mae: 0.0077
# Epoch 38/1000
# 704/704 [==============================] - 2s 2ms/step - loss: 5.7206e-05 - mae: 0.0052 - val_loss: 1.0431e-04 - val_mae: 0.0077
# Epoch 39/1000
# 704/704 [==============================] - 2s 2ms/step - loss: 5.8133e-05 - mae: 0.0051 - val_loss: 1.0874e-04 - val_mae: 0.0080
# Epoch 40/1000
# 704/704 [==============================] - 2s 2ms/step - loss: 5.7530e-05 - mae: 0.0051 - val_loss: 1.0550e-04 - val_mae: 0.0079
# Epoch 41/1000
# 704/704 [==============================] - 2s 2ms/step - loss: 5.7459e-05 - mae: 0.0051 - val_loss: 1.0431e-04 - val_mae: 0.0078
# Epoch 42/1000
# 704/704 [==============================] - 2s 2ms/step - loss: 5.7403e-05 - mae: 0.0052 - val_loss: 1.0199e-04 - val_mae: 0.0076
# Epoch 43/1000
# 704/704 [==============================] - 2s 2ms/step - loss: 5.8032e-05 - mae: 0.0051 - val_loss: 1.0211e-04 - val_mae: 0.0077
# Epoch 44/1000
# 704/704 [==============================] - 2s 2ms/step - loss: 5.7683e-05 - mae: 0.0051 - val_loss: 1.0213e-04 - val_mae: 0.0077
# Epoch 45/1000
# 704/704 [==============================] - 2s 2ms/step - loss: 5.7978e-05 - mae: 0.0051 - val_loss: 1.0202e-04 - val_mae: 0.0076
# Epoch 46/1000
# 704/704 [==============================] - 2s 2ms/step - loss: 5.7652e-05 - mae: 0.0051 - val_loss: 1.0251e-04 - val_mae: 0.0077
# Epoch 47/1000
# 704/704 [==============================] - 2s 2ms/step - loss: 5.7916e-05 - mae: 0.0052 - val_loss: 1.0360e-04 - val_mae: 0.0078
# Epoch 48/1000
# 704/704 [==============================] - 2s 2ms/step - loss: 5.7709e-05 - mae: 0.0052 - val_loss: 1.0237e-04 - val_mae: 0.0076
# Epoch 49/1000
# 704/704 [==============================] - 2s 2ms/step - loss: 5.7959e-05 - mae: 0.0051 - val_loss: 1.0222e-04 - val_mae: 0.0077
# Epoch 50/1000
# 704/704 [==============================] - 2s 2ms/step - loss: 5.8024e-05 - mae: 0.0052 - val_loss: 1.0200e-04 - val_mae: 0.0076
# Epoch 51/1000
# 704/704 [==============================] - 2s 2ms/step - loss: 5.7168e-05 - mae: 0.0051 - val_loss: 1.0201e-04 - val_mae: 0.0076
# Epoch 52/1000
# 704/704 [==============================] - 2s 2ms/step - loss: 5.7276e-05 - mae: 0.0051 - val_loss: 1.0258e-04 - val_mae: 0.0077
# Epoch 53/1000
# 704/704 [==============================] - 2s 2ms/step - loss: 5.7602e-05 - mae: 0.0051 - val_loss: 1.0244e-04 - val_mae: 0.0076
# Epoch 54/1000
# 704/704 [==============================] - 2s 2ms/step - loss: 5.7315e-05 - mae: 0.0051 - val_loss: 1.0200e-04 - val_mae: 0.0076
# Epoch 55/1000
# 704/704 [==============================] - 2s 2ms/step - loss: 5.7675e-05 - mae: 0.0051 - val_loss: 1.0258e-04 - val_mae: 0.0076
# Epoch 56/1000
# 704/704 [==============================] - 2s 2ms/step - loss: 5.7597e-05 - mae: 0.0052 - val_loss: 1.0221e-04 - val_mae: 0.0077
# Epoch 57/1000
# 704/704 [==============================] - 2s 2ms/step - loss: 5.7357e-05 - mae: 0.0051 - val_loss: 1.0314e-04 - val_mae: 0.0077
# Epoch 58/1000
# 704/704 [==============================] - 2s 2ms/step - loss: 5.7417e-05 - mae: 0.0052 - val_loss: 1.0207e-04 - val_mae: 0.0077
# Epoch 59/1000
# 704/704 [==============================] - 2s 2ms/step - loss: 5.7443e-05 - mae: 0.0051 - val_loss: 1.0271e-04 - val_mae: 0.0076
# Epoch 60/1000
# 704/704 [==============================] - 2s 2ms/step - loss: 5.7367e-05 - mae: 0.0051 - val_loss: 1.0247e-04 - val_mae: 0.0076
# Epoch 61/1000
# 704/704 [==============================] - 2s 2ms/step - loss: 5.6788e-05 - mae: 0.0051 - val_loss: 1.0440e-04 - val_mae: 0.0078
# Epoch 62/1000
# 704/704 [==============================] - 2s 2ms/step - loss: 5.6991e-05 - mae: 0.0051 - val_loss: 1.0731e-04 - val_mae: 0.0078
# Epoch 63/1000
# 704/704 [==============================] - 2s 2ms/step - loss: 5.7662e-05 - mae: 0.0051 - val_loss: 1.0205e-04 - val_mae: 0.0077
# Epoch 64/1000
# 704/704 [==============================] - 2s 2ms/step - loss: 5.7250e-05 - mae: 0.0051 - val_loss: 1.0202e-04 - val_mae: 0.0076
# Epoch 65/1000
# 704/704 [==============================] - 2s 2ms/step - loss: 5.7370e-05 - mae: 0.0051 - val_loss: 1.0360e-04 - val_mae: 0.0078
# Epoch 66/1000
# 704/704 [==============================] - 2s 2ms/step - loss: 5.7121e-05 - mae: 0.0051 - val_loss: 1.0312e-04 - val_mae: 0.0076
# Epoch 67/1000
# 704/704 [==============================] - 2s 2ms/step - loss: 5.7532e-05 - mae: 0.0051 - val_loss: 1.0245e-04 - val_mae: 0.0076
# Epoch 68/1000
# 704/704 [==============================] - 2s 2ms/step - loss: 5.7444e-05 - mae: 0.0051 - val_loss: 1.0317e-04 - val_mae: 0.0077
# Epoch 69/1000
# 704/704 [==============================] - 2s 2ms/step - loss: 5.6675e-05 - mae: 0.0051 - val_loss: 1.1473e-04 - val_mae: 0.0081
# Epoch 70/1000
# 704/704 [==============================] - 2s 2ms/step - loss: 5.7619e-05 - mae: 0.0051 - val_loss: 1.0203e-04 - val_mae: 0.0077
# Epoch 71/1000
# 704/704 [==============================] - 2s 2ms/step - loss: 5.6620e-05 - mae: 0.0051 - val_loss: 1.0202e-04 - val_mae: 0.0076
# Epoch 72/1000
# 704/704 [==============================] - 2s 2ms/step - loss: 5.7030e-05 - mae: 0.0051 - val_loss: 1.0273e-04 - val_mae: 0.0077
# Epoch 73/1000
# 704/704 [==============================] - 2s 2ms/step - loss: 5.7274e-05 - mae: 0.0051 - val_loss: 1.0298e-04 - val_mae: 0.0077
# Epoch 74/1000
# 704/704 [==============================] - 2s 2ms/step - loss: 5.7244e-05 - mae: 0.0051 - val_loss: 1.0253e-04 - val_mae: 0.0077
# Epoch 75/1000
# 704/704 [==============================] - 2s 2ms/step - loss: 5.7097e-05 - mae: 0.0051 - val_loss: 1.0207e-04 - val_mae: 0.0076
# Epoch 76/1000
# 704/704 [==============================] - 2s 2ms/step - loss: 5.7269e-05 - mae: 0.0051 - val_loss: 1.0256e-04 - val_mae: 0.0077
# Epoch 77/1000
# 704/704 [==============================] - 2s 2ms/step - loss: 5.6730e-05 - mae: 0.0051 - val_loss: 1.0224e-04 - val_mae: 0.0077
# Epoch 78/1000
# 704/704 [==============================] - 2s 2ms/step - loss: 5.7453e-05 - mae: 0.0051 - val_loss: 1.0240e-04 - val_mae: 0.0077
# Epoch 79/1000
# 704/704 [==============================] - 2s 2ms/step - loss: 5.6952e-05 - mae: 0.0051 - val_loss: 1.0278e-04 - val_mae: 0.0076
# Epoch 80/1000
# 704/704 [==============================] - 2s 2ms/step - loss: 5.6644e-05 - mae: 0.0051 - val_loss: 1.0233e-04 - val_mae: 0.0077
# Epoch 81/1000
# 704/704 [==============================] - 2s 2ms/step - loss: 5.7474e-05 - mae: 0.0051 - val_loss: 1.0208e-04 - val_mae: 0.0077
# Epoch 82/1000
# 704/704 [==============================] - 2s 2ms/step - loss: 5.7372e-05 - mae: 0.0051 - val_loss: 1.0202e-04 - val_mae: 0.0076
# Epoch 83/1000
# 704/704 [==============================] - 2s 2ms/step - loss: 5.7484e-05 - mae: 0.0051 - val_loss: 1.0231e-04 - val_mae: 0.0076
# Epoch 84/1000
# 704/704 [==============================] - 2s 3ms/step - loss: 5.7074e-05 - mae: 0.0051 - val_loss: 1.0207e-04 - val_mae: 0.0077
# Epoch 85/1000
# 704/704 [==============================] - 2s 2ms/step - loss: 5.7069e-05 - mae: 0.0051 - val_loss: 1.0246e-04 - val_mae: 0.0076
# Epoch 86/1000
# 704/704 [==============================] - 2s 2ms/step - loss: 5.7211e-05 - mae: 0.0051 - val_loss: 1.0218e-04 - val_mae: 0.0076
# Epoch 87/1000
# 704/704 [==============================] - 2s 2ms/step - loss: 5.7057e-05 - mae: 0.0051 - val_loss: 1.0497e-04 - val_mae: 0.0078
# Epoch 88/1000
# 704/704 [==============================] - 2s 2ms/step - loss: 5.7237e-05 - mae: 0.0051 - val_loss: 1.0203e-04 - val_mae: 0.0076
# Epoch 89/1000
# 704/704 [==============================] - 2s 2ms/step - loss: 5.7138e-05 - mae: 0.0051 - val_loss: 1.0348e-04 - val_mae: 0.0076
# Epoch 90/1000
# 704/704 [==============================] - 2s 2ms/step - loss: 5.7001e-05 - mae: 0.0051 - val_loss: 1.0204e-04 - val_mae: 0.0076
# Epoch 91/1000
# 704/704 [==============================] - 2s 2ms/step - loss: 5.7355e-05 - mae: 0.0051 - val_loss: 1.0222e-04 - val_mae: 0.0077
# Epoch 92/1000
# 704/704 [==============================] - 2s 2ms/step - loss: 5.6876e-05 - mae: 0.0051 - val_loss: 1.0386e-04 - val_mae: 0.0077
# Epoch 93/1000
# 704/704 [==============================] - 2s 2ms/step - loss: 5.7239e-05 - mae: 0.0051 - val_loss: 1.0290e-04 - val_mae: 0.0077
# Epoch 94/1000
# 704/704 [==============================] - 2s 2ms/step - loss: 5.6861e-05 - mae: 0.0051 - val_loss: 1.0274e-04 - val_mae: 0.0076
# Epoch 95/1000
# 704/704 [==============================] - 2s 2ms/step - loss: 5.6938e-05 - mae: 0.0051 - val_loss: 1.0342e-04 - val_mae: 0.0076
# Epoch 96/1000
# 704/704 [==============================] - 2s 2ms/step - loss: 5.7289e-05 - mae: 0.0051 - val_loss: 1.0204e-04 - val_mae: 0.0076
# Epoch 97/1000
# 704/704 [==============================] - 2s 2ms/step - loss: 5.6331e-05 - mae: 0.0051 - val_loss: 1.0471e-04 - val_mae: 0.0078
# Epoch 98/1000
# 704/704 [==============================] - 2s 2ms/step - loss: 5.7260e-05 - mae: 0.0051 - val_loss: 1.0202e-04 - val_mae: 0.0076
# Epoch 99/1000
# 704/704 [==============================] - 2s 2ms/step - loss: 5.7405e-05 - mae: 0.0051 - val_loss: 1.0246e-04 - val_mae: 0.0077
# Epoch 100/1000
# 704/704 [==============================] - 2s 2ms/step - loss: 5.7187e-05 - mae: 0.0051 - val_loss: 1.0279e-04 - val_mae: 0.0077
# Epoch 101/1000
# 704/704 [==============================] - 2s 2ms/step - loss: 5.6873e-05 - mae: 0.0051 - val_loss: 1.0202e-04 - val_mae: 0.0076
# Epoch 102/1000
# 704/704 [==============================] - 2s 2ms/step - loss: 5.7136e-05 - mae: 0.0051 - val_loss: 1.0715e-04 - val_mae: 0.0079
# Epoch 103/1000
# 704/704 [==============================] - 2s 2ms/step - loss: 5.6886e-05 - mae: 0.0051 - val_loss: 1.0200e-04 - val_mae: 0.0076
# Epoch 104/1000
# 704/704 [==============================] - 2s 2ms/step - loss: 5.7072e-05 - mae: 0.0051 - val_loss: 1.0200e-04 - val_mae: 0.0076
# Epoch 105/1000
# 704/704 [==============================] - 2s 2ms/step - loss: 5.7095e-05 - mae: 0.0051 - val_loss: 1.0237e-04 - val_mae: 0.0077
# Epoch 106/1000
# 704/704 [==============================] - 2s 2ms/step - loss: 5.6538e-05 - mae: 0.0051 - val_loss: 1.0209e-04 - val_mae: 0.0077
# Epoch 107/1000
# 704/704 [==============================] - 2s 2ms/step - loss: 5.7174e-05 - mae: 0.0051 - val_loss: 1.0205e-04 - val_mae: 0.0076
# Epoch 108/1000
# 704/704 [==============================] - 2s 2ms/step - loss: 5.7161e-05 - mae: 0.0051 - val_loss: 1.0492e-04 - val_mae: 0.0078
# Epoch 109/1000
# 704/704 [==============================] - 2s 2ms/step - loss: 5.6844e-05 - mae: 0.0051 - val_loss: 1.0279e-04 - val_mae: 0.0077
# Epoch 110/1000
# 704/704 [==============================] - 2s 2ms/step - loss: 5.6302e-05 - mae: 0.0051 - val_loss: 1.0551e-04 - val_mae: 0.0077
# Epoch 111/1000
# 704/704 [==============================] - 2s 2ms/step - loss: 5.6976e-05 - mae: 0.0051 - val_loss: 1.0400e-04 - val_mae: 0.0078
# Epoch 112/1000
# 704/704 [==============================] - 2s 2ms/step - loss: 5.6671e-05 - mae: 0.0051 - val_loss: 1.0231e-04 - val_mae: 0.0077
# Epoch 113/1000
# 704/704 [==============================] - 2s 2ms/step - loss: 5.6819e-05 - mae: 0.0051 - val_loss: 1.0500e-04 - val_mae: 0.0078
# Epoch 114/1000
# 704/704 [==============================] - 2s 2ms/step - loss: 5.7220e-05 - mae: 0.0051 - val_loss: 1.0207e-04 - val_mae: 0.0077
# Epoch 115/1000
# 704/704 [==============================] - 2s 2ms/step - loss: 5.6630e-05 - mae: 0.0051 - val_loss: 1.0268e-04 - val_mae: 0.0076
# Epoch 116/1000
# 704/704 [==============================] - 2s 2ms/step - loss: 5.6895e-05 - mae: 0.0051 - val_loss: 1.0321e-04 - val_mae: 0.0077
# Epoch 117/1000
# 704/704 [==============================] - 2s 2ms/step - loss: 5.6776e-05 - mae: 0.0051 - val_loss: 1.0207e-04 - val_mae: 0.0076
# Epoch 118/1000
# 704/704 [==============================] - 2s 2ms/step - loss: 5.7171e-05 - mae: 0.0051 - val_loss: 1.0219e-04 - val_mae: 0.0077
# Epoch 119/1000
# 704/704 [==============================] - 2s 2ms/step - loss: 5.7148e-05 - mae: 0.0051 - val_loss: 1.0201e-04 - val_mae: 0.0076
# Epoch 120/1000
# 704/704 [==============================] - 2s 2ms/step - loss: 5.6782e-05 - mae: 0.0051 - val_loss: 1.0252e-04 - val_mae: 0.0076
# Epoch 121/1000
# 704/704 [==============================] - 2s 2ms/step - loss: 5.7009e-05 - mae: 0.0051 - val_loss: 1.0222e-04 - val_mae: 0.0077
# Epoch 122/1000
# 704/704 [==============================] - 2s 2ms/step - loss: 5.6741e-05 - mae: 0.0051 - val_loss: 1.0365e-04 - val_mae: 0.0078
# Epoch 123/1000
# 704/704 [==============================] - 2s 2ms/step - loss: 5.6447e-05 - mae: 0.0051 - val_loss: 1.0209e-04 - val_mae: 0.0077
# Epoch 124/1000
# 704/704 [==============================] - 2s 2ms/step - loss: 5.6793e-05 - mae: 0.0050 - val_loss: 1.0306e-04 - val_mae: 0.0077
# Epoch 125/1000
# 704/704 [==============================] - 2s 2ms/step - loss: 5.6757e-05 - mae: 0.0051 - val_loss: 1.0309e-04 - val_mae: 0.0076
# Epoch 126/1000
# 704/704 [==============================] - 2s 2ms/step - loss: 5.6540e-05 - mae: 0.0051 - val_loss: 1.0380e-04 - val_mae: 0.0078
# Epoch 127/1000
# 704/704 [==============================] - 2s 3ms/step - loss: 5.6710e-05 - mae: 0.0051 - val_loss: 1.0201e-04 - val_mae: 0.0076
# Epoch 128/1000
# 704/704 [==============================] - 2s 2ms/step - loss: 5.6814e-05 - mae: 0.0050 - val_loss: 1.0215e-04 - val_mae: 0.0076
# Epoch 129/1000
# 704/704 [==============================] - 2s 2ms/step - loss: 5.6640e-05 - mae: 0.0051 - val_loss: 1.0391e-04 - val_mae: 0.0077
# Epoch 130/1000
# 704/704 [==============================] - 2s 2ms/step - loss: 5.6841e-05 - mae: 0.0051 - val_loss: 1.0221e-04 - val_mae: 0.0077
# Epoch 131/1000
# 704/704 [==============================] - 2s 2ms/step - loss: 5.6257e-05 - mae: 0.0050 - val_loss: 1.0286e-04 - val_mae: 0.0076
# Epoch 132/1000
# 704/704 [==============================] - 2s 2ms/step - loss: 5.6812e-05 - mae: 0.0051 - val_loss: 1.0201e-04 - val_mae: 0.0076
# Epoch 133/1000
# 704/704 [==============================] - 2s 2ms/step - loss: 5.6818e-05 - mae: 0.0051 - val_loss: 1.0662e-04 - val_mae: 0.0079
# Epoch 134/1000
# 704/704 [==============================] - 2s 2ms/step - loss: 5.7009e-05 - mae: 0.0050 - val_loss: 1.0199e-04 - val_mae: 0.0076
# Epoch 135/1000
# 704/704 [==============================] - 2s 2ms/step - loss: 5.7048e-05 - mae: 0.0050 - val_loss: 1.0280e-04 - val_mae: 0.0077
# Epoch 136/1000
# 704/704 [==============================] - 2s 3ms/step - loss: 5.6677e-05 - mae: 0.0050 - val_loss: 1.0629e-04 - val_mae: 0.0077
# Epoch 137/1000
# 704/704 [==============================] - 2s 2ms/step - loss: 5.6755e-05 - mae: 0.0051 - val_loss: 1.0201e-04 - val_mae: 0.0076
# Epoch 138/1000
# 704/704 [==============================] - 2s 2ms/step - loss: 5.6749e-05 - mae: 0.0051 - val_loss: 1.0335e-04 - val_mae: 0.0076
# Epoch 139/1000
# 704/704 [==============================] - 2s 2ms/step - loss: 5.6648e-05 - mae: 0.0050 - val_loss: 1.0238e-04 - val_mae: 0.0076
# Epoch 140/1000
# 704/704 [==============================] - 2s 2ms/step - loss: 5.6699e-05 - mae: 0.0051 - val_loss: 1.0246e-04 - val_mae: 0.0077
# Epoch 141/1000
# 704/704 [==============================] - 2s 2ms/step - loss: 5.6832e-05 - mae: 0.0051 - val_loss: 1.0205e-04 - val_mae: 0.0077
# Epoch 142/1000
# 704/704 [==============================] - 2s 2ms/step - loss: 5.6481e-05 - mae: 0.0051 - val_loss: 1.0386e-04 - val_mae: 0.0078
# Epoch 143/1000
# 704/704 [==============================] - 2s 2ms/step - loss: 5.6292e-05 - mae: 0.0050 - val_loss: 1.0414e-04 - val_mae: 0.0077
# Epoch 144/1000
# 704/704 [==============================] - 2s 2ms/step - loss: 5.6351e-05 - mae: 0.0051 - val_loss: 1.0370e-04 - val_mae: 0.0076
# Epoch 145/1000
# 704/704 [==============================] - 2s 2ms/step - loss: 5.6510e-05 - mae: 0.0051 - val_loss: 1.0481e-04 - val_mae: 0.0077
# Epoch 146/1000
# 704/704 [==============================] - 2s 2ms/step - loss: 5.6355e-05 - mae: 0.0051 - val_loss: 1.0215e-04 - val_mae: 0.0077
# Epoch 147/1000
# 704/704 [==============================] - 2s 2ms/step - loss: 5.6699e-05 - mae: 0.0051 - val_loss: 1.0222e-04 - val_mae: 0.0077
# Epoch 148/1000
# 704/704 [==============================] - 2s 2ms/step - loss: 5.6342e-05 - mae: 0.0050 - val_loss: 1.0366e-04 - val_mae: 0.0076
# Epoch 149/1000
# 704/704 [==============================] - 2s 2ms/step - loss: 5.6563e-05 - mae: 0.0050 - val_loss: 1.0205e-04 - val_mae: 0.0076
# Epoch 150/1000
# 704/704 [==============================] - 2s 2ms/step - loss: 5.6597e-05 - mae: 0.0051 - val_loss: 1.0203e-04 - val_mae: 0.0076
# Epoch 151/1000
# 704/704 [==============================] - 2s 2ms/step - loss: 5.6561e-05 - mae: 0.0051 - val_loss: 1.0228e-04 - val_mae: 0.0076
# Epoch 152/1000
# 704/704 [==============================] - 2s 2ms/step - loss: 5.6340e-05 - mae: 0.0051 - val_loss: 1.0296e-04 - val_mae: 0.0077
# Epoch 153/1000
# 704/704 [==============================] - 2s 3ms/step - loss: 5.6300e-05 - mae: 0.0051 - val_loss: 1.0206e-04 - val_mae: 0.0076
# Epoch 154/1000
# 704/704 [==============================] - 2s 2ms/step - loss: 5.6765e-05 - mae: 0.0051 - val_loss: 1.0292e-04 - val_mae: 0.0077
# Epoch 155/1000
# 704/704 [==============================] - 2s 2ms/step - loss: 5.6725e-05 - mae: 0.0051 - val_loss: 1.0201e-04 - val_mae: 0.0076
# Epoch 156/1000
# 704/704 [==============================] - 2s 2ms/step - loss: 5.6482e-05 - mae: 0.0050 - val_loss: 1.0209e-04 - val_mae: 0.0077
# Epoch 157/1000
# 704/704 [==============================] - 2s 2ms/step - loss: 5.6271e-05 - mae: 0.0051 - val_loss: 1.0321e-04 - val_mae: 0.0077
# Epoch 158/1000
# 704/704 [==============================] - 2s 2ms/step - loss: 5.6532e-05 - mae: 0.0050 - val_loss: 1.0203e-04 - val_mae: 0.0077
# Epoch 159/1000
# 704/704 [==============================] - 2s 2ms/step - loss: 5.6580e-05 - mae: 0.0051 - val_loss: 1.0211e-04 - val_mae: 0.0077
# Epoch 160/1000
# 704/704 [==============================] - 2s 2ms/step - loss: 5.6451e-05 - mae: 0.0050 - val_loss: 1.0418e-04 - val_mae: 0.0078
# Epoch 161/1000
# 704/704 [==============================] - 2s 2ms/step - loss: 5.6950e-05 - mae: 0.0050 - val_loss: 1.0285e-04 - val_mae: 0.0077
# Epoch 162/1000
# 704/704 [==============================] - 2s 2ms/step - loss: 5.6674e-05 - mae: 0.0050 - val_loss: 1.0284e-04 - val_mae: 0.0076
# Epoch 163/1000
# 704/704 [==============================] - 2s 3ms/step - loss: 5.6639e-05 - mae: 0.0051 - val_loss: 1.0365e-04 - val_mae: 0.0078
# Epoch 164/1000
# 704/704 [==============================] - 2s 3ms/step - loss: 5.6604e-05 - mae: 0.0050 - val_loss: 1.0202e-04 - val_mae: 0.0076
# Epoch 165/1000
# 704/704 [==============================] - 2s 2ms/step - loss: 5.6515e-05 - mae: 0.0050 - val_loss: 1.0303e-04 - val_mae: 0.0077
# Epoch 166/1000
# 704/704 [==============================] - 2s 2ms/step - loss: 5.6708e-05 - mae: 0.0050 - val_loss: 1.0303e-04 - val_mae: 0.0076
# Epoch 167/1000
# 704/704 [==============================] - 2s 2ms/step - loss: 5.6061e-05 - mae: 0.0050 - val_loss: 1.0355e-04 - val_mae: 0.0076
# Epoch 168/1000
# 704/704 [==============================] - 2s 2ms/step - loss: 5.6354e-05 - mae: 0.0051 - val_loss: 1.0397e-04 - val_mae: 0.0078
# Epoch 169/1000
# 704/704 [==============================] - 2s 2ms/step - loss: 5.6664e-05 - mae: 0.0051 - val_loss: 1.0406e-04 - val_mae: 0.0078
# Epoch 170/1000
# 704/704 [==============================] - 2s 2ms/step - loss: 5.6335e-05 - mae: 0.0051 - val_loss: 1.0209e-04 - val_mae: 0.0077
# Epoch 171/1000
# 704/704 [==============================] - 2s 2ms/step - loss: 5.6626e-05 - mae: 0.0050 - val_loss: 1.0199e-04 - val_mae: 0.0076
# Epoch 172/1000
# 704/704 [==============================] - 2s 2ms/step - loss: 5.6524e-05 - mae: 0.0051 - val_loss: 1.0207e-04 - val_mae: 0.0077
# Epoch 173/1000
# 704/704 [==============================] - 2s 2ms/step - loss: 5.6644e-05 - mae: 0.0050 - val_loss: 1.0378e-04 - val_mae: 0.0078
# Epoch 174/1000
# 704/704 [==============================] - 2s 2ms/step - loss: 5.6462e-05 - mae: 0.0050 - val_loss: 1.0243e-04 - val_mae: 0.0077
# Epoch 175/1000
# 704/704 [==============================] - 2s 2ms/step - loss: 5.6680e-05 - mae: 0.0050 - val_loss: 1.0217e-04 - val_mae: 0.0077
# Epoch 176/1000
# 704/704 [==============================] - 2s 2ms/step - loss: 5.6399e-05 - mae: 0.0050 - val_loss: 1.0241e-04 - val_mae: 0.0077
# Epoch 177/1000
# 704/704 [==============================] - 2s 2ms/step - loss: 5.6715e-05 - mae: 0.0050 - val_loss: 1.0199e-04 - val_mae: 0.0076
# Epoch 178/1000
# 704/704 [==============================] - 2s 2ms/step - loss: 5.5876e-05 - mae: 0.0050 - val_loss: 1.0338e-04 - val_mae: 0.0076
# Epoch 179/1000
# 704/704 [==============================] - 2s 2ms/step - loss: 5.6479e-05 - mae: 0.0050 - val_loss: 1.0275e-04 - val_mae: 0.0077
# Epoch 180/1000
# 704/704 [==============================] - 2s 2ms/step - loss: 5.6798e-05 - mae: 0.0050 - val_loss: 1.0231e-04 - val_mae: 0.0077
# Epoch 181/1000
# 704/704 [==============================] - 2s 2ms/step - loss: 5.6375e-05 - mae: 0.0050 - val_loss: 1.0273e-04 - val_mae: 0.0076
# Epoch 182/1000
# 704/704 [==============================] - 2s 2ms/step - loss: 5.6707e-05 - mae: 0.0050 - val_loss: 1.0201e-04 - val_mae: 0.0076
# Epoch 183/1000
# 704/704 [==============================] - 2s 2ms/step - loss: 5.6476e-05 - mae: 0.0050 - val_loss: 1.0200e-04 - val_mae: 0.0076
# Epoch 184/1000
# 704/704 [==============================] - 2s 2ms/step - loss: 5.6649e-05 - mae: 0.0050 - val_loss: 1.0434e-04 - val_mae: 0.0078
# Epoch 185/1000
# 704/704 [==============================] - 2s 2ms/step - loss: 5.6535e-05 - mae: 0.0050 - val_loss: 1.0285e-04 - val_mae: 0.0077
# Epoch 186/1000
# 704/704 [==============================] - 2s 2ms/step - loss: 5.6571e-05 - mae: 0.0050 - val_loss: 1.0201e-04 - val_mae: 0.0076

# %%
model.evaluate(generator_val)
# Out:
# 175/175 [==============================] - 0s 626us/step - loss: 1.0218e-04 - mae: 0.0076
# [0.00010218317765975371, 0.007631364744156599]

# %%
# Learning Curves:
plot_history(history)
# Out:
# array([<AxesSubplot: title={'center': 'MSE'}, xlabel='Epoch', ylabel='Loss'>,
#        <AxesSubplot: title={'center': 'MAE'}, xlabel='Epoch', ylabel='MAE'>],
#       dtype=object)

# %%
#Baseline MAE
0.0048812746058099115

# %% [markdown]
# # Learning Curves viz code:

# %%
def plot_history(history):
    
    fig, ax = plt.subplots(1,2, figsize=(20,7))
    # Loss:MSE
    ax[0].plot(history.history['loss'])
    ax[0].plot(history.history['val_loss'])
    ax[0].set_title('MSE')
    ax[0].set_ylabel('Loss')
    ax[0].set_xlabel('Epoch')
    ax[0].legend(['Train', 'Validation'], loc='best')
    ax[0].grid(axis="x",linewidth=0.5)
    ax[0].grid(axis="y",linewidth=0.5)
    
    # Metrics:MAE
    
    ax[1].plot(history.history['mae'])
    ax[1].plot(history.history['val_mae'])
    ax[1].set_title('MAE')
    ax[1].set_ylabel('MAE')
    ax[1].set_xlabel('Epoch')
    ax[1].legend(['Train', 'Validation'], loc='best')
    ax[1].grid(axis="x",linewidth=0.5)
    ax[1].grid(axis="y",linewidth=0.5)
                        
    return ax
