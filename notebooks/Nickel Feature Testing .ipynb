# %% [markdown]
# # Feature Selection for log_diff_model (Multivariate Model)

# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras import Sequential
from bdi_predict.ml_logic.sequence_gen import WindowGenerator
from tensorflow.keras import layers
from sklearn.model_selection import TimeSeriesSplit
from tensorflow.keras.preprocessing.sequence import TimeseriesGenerator
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import StandardScaler
from tensorflow.keras.optimizers import RMSprop
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.optimizers.schedules import ExponentialDecay
from tensorflow.keras.callbacks import EarlyStopping

# %%
bdi = pd.read_csv("../raw_data/data/BDI/log_diff_BDI_daily.csv")
bdi.head(2)
# Out:
#    Unnamed: 0        Date   Price  abs_price  log_price  log_diff
# 0           0  1995-01-03  1964.0        NaN   3.293141       NaN
# 1           1  1995-01-04  1961.0       -3.0   3.292478 -0.000664

# %%
bdi["Date"] = pd.to_datetime(bdi["Date"])
bdi.set_index("Date", inplace=True)
bdi= bdi[bdi.index != "1995-01-03"]
bdi.drop(columns="Unnamed: 0", inplace=True)
bdi.head(2)
# Out:
#              Price  abs_price  log_price  log_diff
# Date
# 1995-01-04  1961.0       -3.0   3.292478 -0.000664
# 1995-01-05  1967.0        6.0   3.293804  0.001327

# %%
feat = pd.read_csv("../raw_data/data/merged_features.csv")
feat["Date"] = pd.to_datetime(feat["Date"])
feat.set_index("Date", inplace=True)
feat.drop(columns="Unnamed: 0", inplace=True)
feat = feat[["Nickel_x"]]
feat.rename(columns={"Nickel_x":"nickel"}, inplace=True)
nickel=feat
nickel
# Out:
#                   nickel
# Date
# 1995-01-03   8505.450000
# 1995-01-04   8505.450000
# 1995-01-05   8505.450000
# 1995-01-06   8505.450000
# 1995-01-09   8505.450000
# ...                  ...
# 2022-11-08  10264.567966
# 2022-11-09  10003.955424
# 2022-11-10   9743.342881
# 2022-11-11   9482.730339
# 2022-11-14   9222.117797
#
# [7365 rows x 1 columns]

# %%
df = pd.merge(bdi, nickel, on="Date", how="inner")
#df.drop(columns="Price_y", inplace=True)

# %%
df.head(3)
# Out:
#              Price  abs_price  log_price  log_diff   nickel
# Date
# 1995-01-04  1961.0       -3.0   3.292478 -0.000664  8505.45
# 1995-01-05  1967.0        6.0   3.293804  0.001327  8505.45
# 1995-01-06  1983.0       16.0   3.297323  0.003518  8505.45

# %% [markdown]
# # Data Cleaning

# %% [markdown]
# ## Holdout Method (manual, chronological)

# %%
input_length = len(df)

# %%
def train_test_split(df:pd.DataFrame,
                     train_test_ratio: float,
                     input_length: int) -> tuple:
    '''
    Returns a train dataframe and a test dataframe (df_train, df_test)
    from which one can sample (X,y) sequences using TimeseriesGenerator.
    df_train should contain all the timesteps until round(train_test_ratio * len(fold))   
    '''
    
    # TRAIN SET

    last_train_idx = round(train_test_ratio * len(df))
    df_train = df.iloc[0:last_train_idx, :]

    # TEST SET
 
    first_test_idx = last_train_idx - input_length
    df_test = df.iloc[first_test_idx:, :]

    return (df_train, df_test)

# %%
df_train, df_test = train_test_split(df=df, train_test_ratio=0.8, input_length=input_length)

# %%
X_train = df_train[["Price","nickel"]]
y_train = df_train["log_diff"]

X_test  = df_test[["Price","nickel"]]
y_test = df_test["log_diff"]

# %%
#Feature Scaling

scaler_X = MinMaxScaler()

X_train_scaled = scaler_X.fit_transform(X_train)
X_test_scaled = scaler_X.fit_transform(X_test)

# %%
generator = TimeseriesGenerator(X_train_scaled, y_train, length=20, batch_size=8, sampling_rate=1, stride=1)

# %%
len(generator)
# Out:
# 704

# %%
generator_val = TimeseriesGenerator(X_test_scaled, y_test, length=20, batch_size=8, sampling_rate=1, stride=1)

# %%
for X, y in generator:
    print(X.shape, y.shape)
    print(X[0], y[0])
    #listy = [float(X[0][i]) for i in range(len(X[0]))]
    #print(listy)
    break
# Out:
# (8, 20, 2) (8,)
# [[0.14519214 0.09591795]
#  [0.14571379 0.09591795]
#  [0.14710485 0.09591795]
#  [0.14806121 0.09591795]
#  [0.14988698 0.09591795]
#  [0.15023474 0.09591795]
#  [0.15188663 0.09591795]
#  [0.15379934 0.09591795]
#  [0.15440793 0.09591795]
#  [0.15475569 0.09591795]
#  [0.15475569 0.09591795]
#  [0.15466875 0.09591795]
#  [0.1537124  0.09591795]
#  [0.15240828 0.09591795]
#  [0.15136498 0.09591795]
#  [0.1501478  0.09591795]
#  [0.14823509 0.09591795]
#  [0.14710485 0.09591795]
#  [0.1465832  0.09591795]
#  [0.14623544 0.09591795]] -0.0015435717560743

# %% [markdown]
# # The Model

# %%
# Learning Rate Scheduler: 

lr_schedule = ExponentialDecay(
    initial_learning_rate=1e-3,
    decay_steps=10000,
    decay_rate=0.9)

# %%
#Optimizers

rmsprop = RMSprop(learning_rate=lr_schedule) #or 0.001 for inital test
adam = Adam(learning_rate=lr_schedule)

# %%
#Early Stopping Criterion:

es = EarlyStopping(monitor="val_mae", patience=100, restore_best_weights=True)

# %%
#Initializing and compiling model:

def init_model():
    
    model = Sequential()

    #LSTM layers
    model.add(layers.LSTM(60, activation="tanh", input_shape=(20,2), return_sequences=False))

    #Dense layers
    model.add(layers.Dense(100, activation="relu"))
    model.add(layers.Dense(1, activation="linear"))

    #compiling model
    model.compile(loss="mse", optimizer=rmsprop, metrics="mae")
    
    return model

# %% [markdown]
# # Training and Testing

# %%
#Instantiating model

model = init_model()

# %%
#Model layers & params overview:
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_1 (LSTM)               (None, 60)                15120
#
#  dense_2 (Dense)             (None, 100)               6100
#
#  dense_3 (Dense)             (None, 1)                 101
#
# =================================================================
# Total params: 21,321
# Trainable params: 21,321
# Non-trainable params: 0
# _________________________________________________________________

# %%
#TRAINING THE MODEL:

history = model.fit(
    generator, epochs=1000, validation_data=generator_val, shuffle=True, callbacks=es
)
# Out:
# Epoch 1/1000
# 704/704 [==============================] - 4s 4ms/step - loss: 9.3088e-05 - mae: 0.0068 - val_loss: 1.2242e-04 - val_mae: 0.0083
# Epoch 2/1000
# 704/704 [==============================] - 3s 4ms/step - loss: 6.7713e-05 - mae: 0.0057 - val_loss: 1.1620e-04 - val_mae: 0.0083
# Epoch 3/1000
# 704/704 [==============================] - 3s 4ms/step - loss: 6.2242e-05 - mae: 0.0054 - val_loss: 1.0050e-04 - val_mae: 0.0076
# Epoch 4/1000
# 704/704 [==============================] - 3s 4ms/step - loss: 5.9535e-05 - mae: 0.0053 - val_loss: 1.0520e-04 - val_mae: 0.0077
# Epoch 5/1000
# 704/704 [==============================] - 3s 4ms/step - loss: 5.8927e-05 - mae: 0.0052 - val_loss: 1.0487e-04 - val_mae: 0.0078
# Epoch 6/1000
# 704/704 [==============================] - 3s 4ms/step - loss: 5.7730e-05 - mae: 0.0052 - val_loss: 1.0665e-04 - val_mae: 0.0077
# Epoch 7/1000
# 704/704 [==============================] - 3s 4ms/step - loss: 5.9045e-05 - mae: 0.0052 - val_loss: 1.0185e-04 - val_mae: 0.0076
# Epoch 8/1000
# 704/704 [==============================] - 3s 4ms/step - loss: 5.7268e-05 - mae: 0.0051 - val_loss: 1.0190e-04 - val_mae: 0.0077
# Epoch 9/1000
# 704/704 [==============================] - 3s 4ms/step - loss: 5.8710e-05 - mae: 0.0052 - val_loss: 1.0105e-04 - val_mae: 0.0076
# Epoch 10/1000
# 704/704 [==============================] - 3s 4ms/step - loss: 5.7576e-05 - mae: 0.0052 - val_loss: 1.0786e-04 - val_mae: 0.0078
# Epoch 11/1000
# 704/704 [==============================] - 3s 4ms/step - loss: 5.7450e-05 - mae: 0.0051 - val_loss: 1.0344e-04 - val_mae: 0.0076
# Epoch 12/1000
# 704/704 [==============================] - 3s 4ms/step - loss: 5.7336e-05 - mae: 0.0051 - val_loss: 1.3092e-04 - val_mae: 0.0090
# Epoch 13/1000
# 704/704 [==============================] - 3s 4ms/step - loss: 5.7500e-05 - mae: 0.0051 - val_loss: 1.0255e-04 - val_mae: 0.0076
# Epoch 14/1000
# 704/704 [==============================] - 3s 4ms/step - loss: 5.7849e-05 - mae: 0.0051 - val_loss: 1.0320e-04 - val_mae: 0.0078
# Epoch 15/1000
# 704/704 [==============================] - 3s 4ms/step - loss: 5.7159e-05 - mae: 0.0051 - val_loss: 1.0303e-04 - val_mae: 0.0076
# Epoch 16/1000
# 704/704 [==============================] - 3s 4ms/step - loss: 5.7654e-05 - mae: 0.0051 - val_loss: 1.0064e-04 - val_mae: 0.0076
# Epoch 17/1000
# 704/704 [==============================] - 3s 4ms/step - loss: 5.6931e-05 - mae: 0.0051 - val_loss: 1.0255e-04 - val_mae: 0.0076
# Epoch 18/1000
# 704/704 [==============================] - 3s 4ms/step - loss: 5.7868e-05 - mae: 0.0051 - val_loss: 9.9427e-05 - val_mae: 0.0076
# Epoch 19/1000
# 704/704 [==============================] - 3s 4ms/step - loss: 5.6639e-05 - mae: 0.0051 - val_loss: 1.0455e-04 - val_mae: 0.0079
# Epoch 20/1000
# 704/704 [==============================] - 3s 4ms/step - loss: 5.6579e-05 - mae: 0.0051 - val_loss: 1.0148e-04 - val_mae: 0.0075
# Epoch 21/1000
# 704/704 [==============================] - 3s 4ms/step - loss: 5.6839e-05 - mae: 0.0051 - val_loss: 9.7720e-05 - val_mae: 0.0074
# Epoch 22/1000
# 704/704 [==============================] - 3s 4ms/step - loss: 5.6625e-05 - mae: 0.0052 - val_loss: 9.8622e-05 - val_mae: 0.0076
# Epoch 23/1000
# 704/704 [==============================] - 3s 4ms/step - loss: 5.7385e-05 - mae: 0.0052 - val_loss: 9.7955e-05 - val_mae: 0.0076
# Epoch 24/1000
# 704/704 [==============================] - 3s 4ms/step - loss: 5.5983e-05 - mae: 0.0051 - val_loss: 9.1908e-05 - val_mae: 0.0072
# Epoch 25/1000
# 704/704 [==============================] - 3s 4ms/step - loss: 5.4663e-05 - mae: 0.0051 - val_loss: 9.3094e-05 - val_mae: 0.0072
# Epoch 26/1000
# 704/704 [==============================] - 3s 4ms/step - loss: 5.4456e-05 - mae: 0.0050 - val_loss: 9.0411e-05 - val_mae: 0.0071
# Epoch 27/1000
# 704/704 [==============================] - 3s 4ms/step - loss: 5.4285e-05 - mae: 0.0050 - val_loss: 8.7374e-05 - val_mae: 0.0071
# Epoch 28/1000
# 704/704 [==============================] - 3s 4ms/step - loss: 5.3176e-05 - mae: 0.0050 - val_loss: 8.6363e-05 - val_mae: 0.0070
# Epoch 29/1000
# 704/704 [==============================] - 3s 4ms/step - loss: 5.1713e-05 - mae: 0.0050 - val_loss: 8.5619e-05 - val_mae: 0.0071
# Epoch 30/1000
# 704/704 [==============================] - 3s 4ms/step - loss: 5.1373e-05 - mae: 0.0049 - val_loss: 9.3346e-05 - val_mae: 0.0073
# Epoch 31/1000
# 704/704 [==============================] - 3s 4ms/step - loss: 5.1995e-05 - mae: 0.0049 - val_loss: 8.6088e-05 - val_mae: 0.0070
# Epoch 32/1000
# 704/704 [==============================] - 3s 4ms/step - loss: 5.0027e-05 - mae: 0.0049 - val_loss: 8.0588e-05 - val_mae: 0.0068
# Epoch 33/1000
# 704/704 [==============================] - 3s 4ms/step - loss: 5.0689e-05 - mae: 0.0049 - val_loss: 8.6159e-05 - val_mae: 0.0072
# Epoch 34/1000
# 704/704 [==============================] - 3s 4ms/step - loss: 5.0624e-05 - mae: 0.0049 - val_loss: 8.7085e-05 - val_mae: 0.0071
# Epoch 35/1000
# 704/704 [==============================] - 3s 4ms/step - loss: 5.0807e-05 - mae: 0.0049 - val_loss: 8.0985e-05 - val_mae: 0.0069
# Epoch 36/1000
# 704/704 [==============================] - 3s 4ms/step - loss: 4.9916e-05 - mae: 0.0048 - val_loss: 9.4740e-05 - val_mae: 0.0074
# Epoch 37/1000
# 704/704 [==============================] - 3s 4ms/step - loss: 4.9794e-05 - mae: 0.0049 - val_loss: 8.3845e-05 - val_mae: 0.0070
# Epoch 38/1000
# 704/704 [==============================] - 3s 4ms/step - loss: 4.9881e-05 - mae: 0.0048 - val_loss: 8.1011e-05 - val_mae: 0.0069
# Epoch 39/1000
# 704/704 [==============================] - 3s 4ms/step - loss: 4.9557e-05 - mae: 0.0049 - val_loss: 9.7929e-05 - val_mae: 0.0077
# Epoch 40/1000
# 704/704 [==============================] - 3s 4ms/step - loss: 5.0485e-05 - mae: 0.0048 - val_loss: 8.3146e-05 - val_mae: 0.0070
# Epoch 41/1000
# 704/704 [==============================] - 3s 4ms/step - loss: 4.9640e-05 - mae: 0.0048 - val_loss: 1.0233e-04 - val_mae: 0.0078
# Epoch 42/1000
# 704/704 [==============================] - 3s 4ms/step - loss: 4.9596e-05 - mae: 0.0048 - val_loss: 7.7319e-05 - val_mae: 0.0068
# Epoch 43/1000
# 704/704 [==============================] - 3s 4ms/step - loss: 4.9437e-05 - mae: 0.0048 - val_loss: 8.0191e-05 - val_mae: 0.0070
# Epoch 44/1000
# 704/704 [==============================] - 3s 4ms/step - loss: 4.8855e-05 - mae: 0.0048 - val_loss: 8.8724e-05 - val_mae: 0.0073
# Epoch 45/1000
# 704/704 [==============================] - 3s 4ms/step - loss: 4.8630e-05 - mae: 0.0048 - val_loss: 9.1556e-05 - val_mae: 0.0072
# Epoch 46/1000
# 704/704 [==============================] - 3s 5ms/step - loss: 4.9285e-05 - mae: 0.0048 - val_loss: 8.1254e-05 - val_mae: 0.0069
# Epoch 47/1000
# 704/704 [==============================] - 4s 5ms/step - loss: 4.8574e-05 - mae: 0.0048 - val_loss: 8.0741e-05 - val_mae: 0.0069
# Epoch 48/1000
# 704/704 [==============================] - 3s 4ms/step - loss: 4.8786e-05 - mae: 0.0048 - val_loss: 8.1553e-05 - val_mae: 0.0069
# Epoch 49/1000
# 704/704 [==============================] - 3s 4ms/step - loss: 4.7802e-05 - mae: 0.0047 - val_loss: 7.8780e-05 - val_mae: 0.0068
# Epoch 50/1000
# 704/704 [==============================] - 3s 4ms/step - loss: 4.9175e-05 - mae: 0.0048 - val_loss: 9.3724e-05 - val_mae: 0.0073
# Epoch 51/1000
# 704/704 [==============================] - 3s 4ms/step - loss: 4.8188e-05 - mae: 0.0048 - val_loss: 8.4409e-05 - val_mae: 0.0071
# Epoch 52/1000
# 704/704 [==============================] - 3s 4ms/step - loss: 4.8068e-05 - mae: 0.0047 - val_loss: 7.5639e-05 - val_mae: 0.0068
# Epoch 53/1000
# 704/704 [==============================] - 3s 4ms/step - loss: 4.8135e-05 - mae: 0.0047 - val_loss: 7.8877e-05 - val_mae: 0.0068
# Epoch 54/1000
# 704/704 [==============================] - 3s 4ms/step - loss: 4.7602e-05 - mae: 0.0047 - val_loss: 8.4667e-05 - val_mae: 0.0071
# Epoch 55/1000
# 704/704 [==============================] - 3s 4ms/step - loss: 4.6927e-05 - mae: 0.0047 - val_loss: 7.9752e-05 - val_mae: 0.0068
# Epoch 56/1000
# 704/704 [==============================] - 3s 4ms/step - loss: 4.7108e-05 - mae: 0.0046 - val_loss: 8.1013e-05 - val_mae: 0.0070
# Epoch 57/1000
# 704/704 [==============================] - 3s 4ms/step - loss: 4.7171e-05 - mae: 0.0047 - val_loss: 7.6162e-05 - val_mae: 0.0068
# Epoch 58/1000
# 704/704 [==============================] - 3s 4ms/step - loss: 4.7241e-05 - mae: 0.0047 - val_loss: 7.7592e-05 - val_mae: 0.0067
# Epoch 59/1000
# 704/704 [==============================] - 3s 4ms/step - loss: 4.7445e-05 - mae: 0.0047 - val_loss: 7.6942e-05 - val_mae: 0.0068
# Epoch 60/1000
# 704/704 [==============================] - 3s 4ms/step - loss: 4.6631e-05 - mae: 0.0047 - val_loss: 7.4716e-05 - val_mae: 0.0067
# Epoch 61/1000
# 704/704 [==============================] - 3s 4ms/step - loss: 4.7051e-05 - mae: 0.0047 - val_loss: 7.2155e-05 - val_mae: 0.0065
# Epoch 62/1000
# 704/704 [==============================] - 3s 4ms/step - loss: 4.5533e-05 - mae: 0.0046 - val_loss: 6.9009e-05 - val_mae: 0.0065
# Epoch 63/1000
# 704/704 [==============================] - 3s 4ms/step - loss: 4.5795e-05 - mae: 0.0046 - val_loss: 7.2451e-05 - val_mae: 0.0065
# Epoch 64/1000
# 704/704 [==============================] - 3s 4ms/step - loss: 4.6106e-05 - mae: 0.0046 - val_loss: 6.9944e-05 - val_mae: 0.0064
# Epoch 65/1000
# 704/704 [==============================] - 3s 4ms/step - loss: 4.6017e-05 - mae: 0.0046 - val_loss: 6.7762e-05 - val_mae: 0.0064
# Epoch 66/1000
# 704/704 [==============================] - 3s 4ms/step - loss: 4.5032e-05 - mae: 0.0046 - val_loss: 6.6951e-05 - val_mae: 0.0063
# Epoch 67/1000
# 704/704 [==============================] - 3s 4ms/step - loss: 4.4889e-05 - mae: 0.0046 - val_loss: 6.9250e-05 - val_mae: 0.0063
# Epoch 68/1000
# 704/704 [==============================] - 3s 4ms/step - loss: 4.4160e-05 - mae: 0.0045 - val_loss: 6.5748e-05 - val_mae: 0.0062
# Epoch 69/1000
# 704/704 [==============================] - 3s 4ms/step - loss: 4.3720e-05 - mae: 0.0044 - val_loss: 6.6441e-05 - val_mae: 0.0063
# Epoch 70/1000
# 704/704 [==============================] - 3s 4ms/step - loss: 4.3169e-05 - mae: 0.0044 - val_loss: 6.5922e-05 - val_mae: 0.0061
# Epoch 71/1000
# 704/704 [==============================] - 3s 4ms/step - loss: 4.2069e-05 - mae: 0.0044 - val_loss: 6.1734e-05 - val_mae: 0.0060
# Epoch 72/1000
# 704/704 [==============================] - 3s 4ms/step - loss: 4.1314e-05 - mae: 0.0044 - val_loss: 6.1840e-05 - val_mae: 0.0060
# Epoch 73/1000
# 704/704 [==============================] - 3s 4ms/step - loss: 4.0444e-05 - mae: 0.0043 - val_loss: 5.2915e-05 - val_mae: 0.0054
# Epoch 74/1000
# 704/704 [==============================] - 3s 4ms/step - loss: 3.9382e-05 - mae: 0.0043 - val_loss: 5.3117e-05 - val_mae: 0.0053
# Epoch 75/1000
# 704/704 [==============================] - 3s 4ms/step - loss: 3.8635e-05 - mae: 0.0042 - val_loss: 4.6682e-05 - val_mae: 0.0049
# Epoch 76/1000
# 704/704 [==============================] - 3s 4ms/step - loss: 3.7085e-05 - mae: 0.0041 - val_loss: 4.6900e-05 - val_mae: 0.0050
# Epoch 77/1000
# 704/704 [==============================] - 3s 4ms/step - loss: 3.6086e-05 - mae: 0.0041 - val_loss: 4.2633e-05 - val_mae: 0.0045
# Epoch 78/1000
# 704/704 [==============================] - 3s 4ms/step - loss: 3.5476e-05 - mae: 0.0040 - val_loss: 4.8123e-05 - val_mae: 0.0047
# Epoch 79/1000
# 704/704 [==============================] - 3s 4ms/step - loss: 3.4762e-05 - mae: 0.0040 - val_loss: 4.1457e-05 - val_mae: 0.0045
# Epoch 80/1000
# 704/704 [==============================] - 3s 4ms/step - loss: 3.4653e-05 - mae: 0.0040 - val_loss: 4.6469e-05 - val_mae: 0.0048
# Epoch 81/1000
# 704/704 [==============================] - 3s 4ms/step - loss: 3.3528e-05 - mae: 0.0039 - val_loss: 3.9224e-05 - val_mae: 0.0044
# Epoch 82/1000
# 704/704 [==============================] - 3s 4ms/step - loss: 3.3598e-05 - mae: 0.0039 - val_loss: 4.3342e-05 - val_mae: 0.0047
# Epoch 83/1000
# 704/704 [==============================] - 3s 4ms/step - loss: 3.2311e-05 - mae: 0.0038 - val_loss: 3.4425e-05 - val_mae: 0.0039
# Epoch 84/1000
# 704/704 [==============================] - 3s 4ms/step - loss: 3.1883e-05 - mae: 0.0038 - val_loss: 3.7167e-05 - val_mae: 0.0039
# Epoch 85/1000
# 704/704 [==============================] - 3s 4ms/step - loss: 3.1448e-05 - mae: 0.0037 - val_loss: 4.1319e-05 - val_mae: 0.0046
# Epoch 86/1000
# 704/704 [==============================] - 3s 4ms/step - loss: 3.1058e-05 - mae: 0.0037 - val_loss: 4.9413e-05 - val_mae: 0.0048
# Epoch 87/1000
# 704/704 [==============================] - 3s 4ms/step - loss: 3.0268e-05 - mae: 0.0037 - val_loss: 3.7034e-05 - val_mae: 0.0038
# Epoch 88/1000
# 704/704 [==============================] - 3s 4ms/step - loss: 2.9872e-05 - mae: 0.0037 - val_loss: 4.4225e-05 - val_mae: 0.0047
# Epoch 89/1000
# 704/704 [==============================] - 3s 4ms/step - loss: 2.9169e-05 - mae: 0.0036 - val_loss: 3.2914e-05 - val_mae: 0.0038
# Epoch 90/1000
# 704/704 [==============================] - 3s 4ms/step - loss: 2.9462e-05 - mae: 0.0036 - val_loss: 3.4919e-05 - val_mae: 0.0036
# Epoch 91/1000
# 704/704 [==============================] - 3s 4ms/step - loss: 2.8885e-05 - mae: 0.0036 - val_loss: 3.3444e-05 - val_mae: 0.0036
# Epoch 92/1000
# 704/704 [==============================] - 3s 4ms/step - loss: 2.7903e-05 - mae: 0.0035 - val_loss: 3.3874e-05 - val_mae: 0.0036
# Epoch 93/1000
# 704/704 [==============================] - 3s 4ms/step - loss: 2.7734e-05 - mae: 0.0035 - val_loss: 3.2526e-05 - val_mae: 0.0034
# Epoch 94/1000
# 704/704 [==============================] - 3s 4ms/step - loss: 2.7398e-05 - mae: 0.0035 - val_loss: 3.3872e-05 - val_mae: 0.0036
# Epoch 95/1000
# 704/704 [==============================] - 3s 4ms/step - loss: 2.6960e-05 - mae: 0.0034 - val_loss: 3.3006e-05 - val_mae: 0.0040
# Epoch 96/1000
# 704/704 [==============================] - 3s 4ms/step - loss: 2.6784e-05 - mae: 0.0034 - val_loss: 3.3437e-05 - val_mae: 0.0035
# Epoch 97/1000
# 704/704 [==============================] - 3s 4ms/step - loss: 2.6411e-05 - mae: 0.0034 - val_loss: 3.3743e-05 - val_mae: 0.0037
# Epoch 98/1000
# 704/704 [==============================] - 3s 4ms/step - loss: 2.5828e-05 - mae: 0.0034 - val_loss: 4.0619e-05 - val_mae: 0.0043
# Epoch 99/1000
# 704/704 [==============================] - 3s 4ms/step - loss: 2.5641e-05 - mae: 0.0033 - val_loss: 3.2843e-05 - val_mae: 0.0034
# Epoch 100/1000
# 704/704 [==============================] - 3s 4ms/step - loss: 2.4901e-05 - mae: 0.0033 - val_loss: 3.4844e-05 - val_mae: 0.0038
# Epoch 101/1000
# 704/704 [==============================] - 3s 4ms/step - loss: 2.4610e-05 - mae: 0.0033 - val_loss: 3.7378e-05 - val_mae: 0.0039
# Epoch 102/1000
# 704/704 [==============================] - 3s 5ms/step - loss: 2.4400e-05 - mae: 0.0033 - val_loss: 3.7898e-05 - val_mae: 0.0037
# Epoch 103/1000
# 704/704 [==============================] - 4s 5ms/step - loss: 2.4487e-05 - mae: 0.0032 - val_loss: 3.1994e-05 - val_mae: 0.0033
# Epoch 104/1000
# 704/704 [==============================] - 4s 5ms/step - loss: 2.4349e-05 - mae: 0.0032 - val_loss: 3.0318e-05 - val_mae: 0.0032
# Epoch 105/1000
# 704/704 [==============================] - 3s 5ms/step - loss: 2.3650e-05 - mae: 0.0032 - val_loss: 3.1468e-05 - val_mae: 0.0033
# Epoch 106/1000
# 704/704 [==============================] - 3s 4ms/step - loss: 2.3703e-05 - mae: 0.0032 - val_loss: 3.3859e-05 - val_mae: 0.0035
# Epoch 107/1000
# 704/704 [==============================] - 3s 4ms/step - loss: 2.3789e-05 - mae: 0.0032 - val_loss: 3.3997e-05 - val_mae: 0.0035
# Epoch 108/1000
# 704/704 [==============================] - 3s 4ms/step - loss: 2.3352e-05 - mae: 0.0031 - val_loss: 3.2200e-05 - val_mae: 0.0033
# Epoch 109/1000
# 704/704 [==============================] - 4s 5ms/step - loss: 2.3404e-05 - mae: 0.0032 - val_loss: 3.2364e-05 - val_mae: 0.0035
# Epoch 110/1000
# 704/704 [==============================] - 3s 4ms/step - loss: 2.3010e-05 - mae: 0.0031 - val_loss: 3.6297e-05 - val_mae: 0.0040
# Epoch 111/1000
# 704/704 [==============================] - 3s 4ms/step - loss: 2.3097e-05 - mae: 0.0032 - val_loss: 3.4389e-05 - val_mae: 0.0038
# Epoch 112/1000
# 704/704 [==============================] - 3s 4ms/step - loss: 2.2699e-05 - mae: 0.0031 - val_loss: 3.4618e-05 - val_mae: 0.0038
# Epoch 113/1000
# 704/704 [==============================] - 3s 5ms/step - loss: 2.2676e-05 - mae: 0.0031 - val_loss: 3.1304e-05 - val_mae: 0.0034
# Epoch 114/1000
# 704/704 [==============================] - 3s 4ms/step - loss: 2.2588e-05 - mae: 0.0031 - val_loss: 3.2055e-05 - val_mae: 0.0037
# Epoch 115/1000
# 704/704 [==============================] - 3s 4ms/step - loss: 2.2638e-05 - mae: 0.0031 - val_loss: 3.3493e-05 - val_mae: 0.0038
# Epoch 116/1000
# 704/704 [==============================] - 3s 4ms/step - loss: 2.2501e-05 - mae: 0.0031 - val_loss: 3.1450e-05 - val_mae: 0.0032
# Epoch 117/1000
# 704/704 [==============================] - 3s 4ms/step - loss: 2.2576e-05 - mae: 0.0030 - val_loss: 3.3305e-05 - val_mae: 0.0035
# Epoch 118/1000
# 704/704 [==============================] - 3s 4ms/step - loss: 2.2626e-05 - mae: 0.0031 - val_loss: 3.1216e-05 - val_mae: 0.0034
# Epoch 119/1000
# 704/704 [==============================] - 3s 4ms/step - loss: 2.2176e-05 - mae: 0.0030 - val_loss: 3.4470e-05 - val_mae: 0.0038
# Epoch 120/1000
# 704/704 [==============================] - 3s 4ms/step - loss: 2.2254e-05 - mae: 0.0031 - val_loss: 3.7096e-05 - val_mae: 0.0039
# Epoch 121/1000
# 704/704 [==============================] - 3s 4ms/step - loss: 2.1973e-05 - mae: 0.0030 - val_loss: 3.1898e-05 - val_mae: 0.0033
# Epoch 122/1000
# 704/704 [==============================] - 3s 4ms/step - loss: 2.1996e-05 - mae: 0.0030 - val_loss: 3.3155e-05 - val_mae: 0.0034
# Epoch 123/1000
# 704/704 [==============================] - 3s 4ms/step - loss: 2.1985e-05 - mae: 0.0030 - val_loss: 3.7176e-05 - val_mae: 0.0041
# Epoch 124/1000
# 704/704 [==============================] - 3s 4ms/step - loss: 2.1859e-05 - mae: 0.0030 - val_loss: 3.1405e-05 - val_mae: 0.0033
# Epoch 125/1000
# 704/704 [==============================] - 3s 4ms/step - loss: 2.1791e-05 - mae: 0.0030 - val_loss: 3.1011e-05 - val_mae: 0.0034
# Epoch 126/1000
# 704/704 [==============================] - 3s 4ms/step - loss: 2.1588e-05 - mae: 0.0030 - val_loss: 3.4878e-05 - val_mae: 0.0038
# Epoch 127/1000
# 704/704 [==============================] - 3s 4ms/step - loss: 2.1513e-05 - mae: 0.0030 - val_loss: 3.1907e-05 - val_mae: 0.0034
# Epoch 128/1000
# 704/704 [==============================] - 3s 4ms/step - loss: 2.1312e-05 - mae: 0.0030 - val_loss: 3.2136e-05 - val_mae: 0.0033
# Epoch 129/1000
# 704/704 [==============================] - 3s 4ms/step - loss: 2.1302e-05 - mae: 0.0030 - val_loss: 3.1672e-05 - val_mae: 0.0033
# Epoch 130/1000
# 704/704 [==============================] - 3s 4ms/step - loss: 2.1331e-05 - mae: 0.0030 - val_loss: 3.2170e-05 - val_mae: 0.0035
# Epoch 131/1000
# 704/704 [==============================] - 3s 4ms/step - loss: 2.1455e-05 - mae: 0.0030 - val_loss: 3.1438e-05 - val_mae: 0.0034
# Epoch 132/1000
# 704/704 [==============================] - 3s 4ms/step - loss: 2.1166e-05 - mae: 0.0030 - val_loss: 3.2039e-05 - val_mae: 0.0034
# Epoch 133/1000
# 704/704 [==============================] - 3s 4ms/step - loss: 2.1068e-05 - mae: 0.0030 - val_loss: 3.2130e-05 - val_mae: 0.0033
# Epoch 134/1000
# 704/704 [==============================] - 3s 4ms/step - loss: 2.1074e-05 - mae: 0.0029 - val_loss: 3.2055e-05 - val_mae: 0.0033
# Epoch 135/1000
# 704/704 [==============================] - 3s 4ms/step - loss: 2.0919e-05 - mae: 0.0029 - val_loss: 3.3362e-05 - val_mae: 0.0036
# Epoch 136/1000
# 704/704 [==============================] - 3s 4ms/step - loss: 2.1002e-05 - mae: 0.0029 - val_loss: 3.3260e-05 - val_mae: 0.0035
# Epoch 137/1000
# 704/704 [==============================] - 3s 4ms/step - loss: 2.0781e-05 - mae: 0.0029 - val_loss: 3.0978e-05 - val_mae: 0.0036
# Epoch 138/1000
# 704/704 [==============================] - 3s 4ms/step - loss: 2.0664e-05 - mae: 0.0029 - val_loss: 3.4292e-05 - val_mae: 0.0037
# Epoch 139/1000
# 704/704 [==============================] - 3s 4ms/step - loss: 2.0409e-05 - mae: 0.0029 - val_loss: 3.2200e-05 - val_mae: 0.0036
# Epoch 140/1000
# 704/704 [==============================] - 3s 4ms/step - loss: 2.0637e-05 - mae: 0.0029 - val_loss: 3.4672e-05 - val_mae: 0.0037
# Epoch 141/1000
# 704/704 [==============================] - 3s 4ms/step - loss: 2.0278e-05 - mae: 0.0029 - val_loss: 3.2592e-05 - val_mae: 0.0034
# Epoch 142/1000
# 704/704 [==============================] - 3s 4ms/step - loss: 2.0471e-05 - mae: 0.0029 - val_loss: 4.4825e-05 - val_mae: 0.0047
# Epoch 143/1000
# 704/704 [==============================] - 3s 4ms/step - loss: 2.0396e-05 - mae: 0.0029 - val_loss: 3.3669e-05 - val_mae: 0.0035
# Epoch 144/1000
# 704/704 [==============================] - 3s 4ms/step - loss: 2.0727e-05 - mae: 0.0029 - val_loss: 3.1282e-05 - val_mae: 0.0034
# Epoch 145/1000
# 704/704 [==============================] - 3s 4ms/step - loss: 2.0314e-05 - mae: 0.0029 - val_loss: 3.2909e-05 - val_mae: 0.0035
# Epoch 146/1000
# 704/704 [==============================] - 3s 4ms/step - loss: 2.0267e-05 - mae: 0.0029 - val_loss: 3.2632e-05 - val_mae: 0.0034
# Epoch 147/1000
# 704/704 [==============================] - 3s 5ms/step - loss: 2.0105e-05 - mae: 0.0029 - val_loss: 3.6456e-05 - val_mae: 0.0038
# Epoch 148/1000
# 704/704 [==============================] - 3s 5ms/step - loss: 2.0311e-05 - mae: 0.0029 - val_loss: 3.8714e-05 - val_mae: 0.0044
# Epoch 149/1000
# 704/704 [==============================] - 3s 4ms/step - loss: 2.0312e-05 - mae: 0.0029 - val_loss: 3.3213e-05 - val_mae: 0.0035
# Epoch 150/1000
# 704/704 [==============================] - 3s 4ms/step - loss: 2.0367e-05 - mae: 0.0029 - val_loss: 3.1732e-05 - val_mae: 0.0034
# Epoch 151/1000
# 704/704 [==============================] - 3s 4ms/step - loss: 2.0311e-05 - mae: 0.0029 - val_loss: 3.2786e-05 - val_mae: 0.0035
# Epoch 152/1000
# 704/704 [==============================] - 3s 4ms/step - loss: 2.0043e-05 - mae: 0.0028 - val_loss: 3.1135e-05 - val_mae: 0.0032
# Epoch 153/1000
# 704/704 [==============================] - 3s 4ms/step - loss: 1.9983e-05 - mae: 0.0028 - val_loss: 3.2333e-05 - val_mae: 0.0035
# Epoch 154/1000
# 704/704 [==============================] - 3s 4ms/step - loss: 2.0181e-05 - mae: 0.0029 - val_loss: 3.2596e-05 - val_mae: 0.0034
# Epoch 155/1000
# 704/704 [==============================] - 3s 4ms/step - loss: 1.9937e-05 - mae: 0.0028 - val_loss: 3.5138e-05 - val_mae: 0.0037
# Epoch 156/1000
# 704/704 [==============================] - 3s 4ms/step - loss: 1.9984e-05 - mae: 0.0028 - val_loss: 3.3169e-05 - val_mae: 0.0035
# Epoch 157/1000
# 704/704 [==============================] - 3s 4ms/step - loss: 1.9914e-05 - mae: 0.0028 - val_loss: 4.0202e-05 - val_mae: 0.0045
# Epoch 158/1000
# 704/704 [==============================] - 3s 4ms/step - loss: 1.9767e-05 - mae: 0.0028 - val_loss: 3.2422e-05 - val_mae: 0.0033
# Epoch 159/1000
# 704/704 [==============================] - 3s 4ms/step - loss: 1.9684e-05 - mae: 0.0028 - val_loss: 3.4882e-05 - val_mae: 0.0037
# Epoch 160/1000
# 704/704 [==============================] - 4s 5ms/step - loss: 1.9916e-05 - mae: 0.0028 - val_loss: 3.1613e-05 - val_mae: 0.0035
# Epoch 161/1000
# 704/704 [==============================] - 3s 4ms/step - loss: 1.9701e-05 - mae: 0.0028 - val_loss: 3.4422e-05 - val_mae: 0.0037
# Epoch 162/1000
# 704/704 [==============================] - 3s 4ms/step - loss: 1.9599e-05 - mae: 0.0028 - val_loss: 3.6651e-05 - val_mae: 0.0038
# Epoch 163/1000
# 704/704 [==============================] - 3s 4ms/step - loss: 1.9703e-05 - mae: 0.0028 - val_loss: 3.3145e-05 - val_mae: 0.0035
# Epoch 164/1000
# 704/704 [==============================] - 3s 4ms/step - loss: 1.9652e-05 - mae: 0.0028 - val_loss: 3.2935e-05 - val_mae: 0.0034
# Epoch 165/1000
# 704/704 [==============================] - 3s 4ms/step - loss: 1.9614e-05 - mae: 0.0028 - val_loss: 3.3676e-05 - val_mae: 0.0037
# Epoch 166/1000
# 704/704 [==============================] - 3s 4ms/step - loss: 1.9996e-05 - mae: 0.0028 - val_loss: 3.3288e-05 - val_mae: 0.0036
# Epoch 167/1000
# 704/704 [==============================] - 3s 4ms/step - loss: 1.9442e-05 - mae: 0.0028 - val_loss: 3.3226e-05 - val_mae: 0.0035
# Epoch 168/1000
# 704/704 [==============================] - 3s 5ms/step - loss: 1.9571e-05 - mae: 0.0028 - val_loss: 3.3900e-05 - val_mae: 0.0037
# Epoch 169/1000
# 704/704 [==============================] - 4s 6ms/step - loss: 1.9611e-05 - mae: 0.0028 - val_loss: 3.2701e-05 - val_mae: 0.0034
# Epoch 170/1000
# 704/704 [==============================] - 3s 4ms/step - loss: 1.9591e-05 - mae: 0.0028 - val_loss: 3.3972e-05 - val_mae: 0.0036
# Epoch 171/1000
# 704/704 [==============================] - 3s 4ms/step - loss: 1.9469e-05 - mae: 0.0028 - val_loss: 3.8056e-05 - val_mae: 0.0040
# Epoch 172/1000
# 704/704 [==============================] - 3s 4ms/step - loss: 1.9306e-05 - mae: 0.0028 - val_loss: 3.3556e-05 - val_mae: 0.0036
# Epoch 173/1000
# 704/704 [==============================] - 3s 4ms/step - loss: 1.9301e-05 - mae: 0.0028 - val_loss: 3.6165e-05 - val_mae: 0.0038
# Epoch 174/1000
# 704/704 [==============================] - 3s 4ms/step - loss: 1.9126e-05 - mae: 0.0028 - val_loss: 3.4608e-05 - val_mae: 0.0037
# Epoch 175/1000
# 704/704 [==============================] - 3s 4ms/step - loss: 1.9454e-05 - mae: 0.0028 - val_loss: 3.5110e-05 - val_mae: 0.0036
# Epoch 176/1000
# 704/704 [==============================] - 3s 4ms/step - loss: 1.9489e-05 - mae: 0.0028 - val_loss: 3.3199e-05 - val_mae: 0.0037
# Epoch 177/1000
# 704/704 [==============================] - 3s 4ms/step - loss: 1.9218e-05 - mae: 0.0028 - val_loss: 3.3877e-05 - val_mae: 0.0036
# Epoch 178/1000
# 704/704 [==============================] - 3s 4ms/step - loss: 1.9133e-05 - mae: 0.0028 - val_loss: 3.6556e-05 - val_mae: 0.0038
# Epoch 179/1000
# 704/704 [==============================] - 3s 4ms/step - loss: 1.9283e-05 - mae: 0.0028 - val_loss: 3.3286e-05 - val_mae: 0.0034
# Epoch 180/1000
# 704/704 [==============================] - 3s 4ms/step - loss: 1.8999e-05 - mae: 0.0027 - val_loss: 3.3894e-05 - val_mae: 0.0035
# Epoch 181/1000
# 704/704 [==============================] - 3s 4ms/step - loss: 1.9232e-05 - mae: 0.0028 - val_loss: 3.5006e-05 - val_mae: 0.0038
# Epoch 182/1000
# 704/704 [==============================] - 3s 4ms/step - loss: 1.9358e-05 - mae: 0.0028 - val_loss: 3.3985e-05 - val_mae: 0.0036
# Epoch 183/1000
# 704/704 [==============================] - 3s 4ms/step - loss: 1.9071e-05 - mae: 0.0027 - val_loss: 3.7009e-05 - val_mae: 0.0037
# Epoch 184/1000
# 704/704 [==============================] - 3s 4ms/step - loss: 1.9181e-05 - mae: 0.0027 - val_loss: 3.6411e-05 - val_mae: 0.0038
# Epoch 185/1000
# 704/704 [==============================] - 3s 4ms/step - loss: 1.9044e-05 - mae: 0.0028 - val_loss: 3.5738e-05 - val_mae: 0.0036
# Epoch 186/1000
# 704/704 [==============================] - 3s 4ms/step - loss: 1.9006e-05 - mae: 0.0028 - val_loss: 3.6737e-05 - val_mae: 0.0038
# Epoch 187/1000
# 704/704 [==============================] - 3s 4ms/step - loss: 1.9160e-05 - mae: 0.0027 - val_loss: 3.9169e-05 - val_mae: 0.0042
# Epoch 188/1000
# 704/704 [==============================] - 3s 4ms/step - loss: 1.9021e-05 - mae: 0.0027 - val_loss: 3.9335e-05 - val_mae: 0.0040
# Epoch 189/1000
# 704/704 [==============================] - 3s 4ms/step - loss: 1.8825e-05 - mae: 0.0027 - val_loss: 3.7664e-05 - val_mae: 0.0039
# Epoch 190/1000
# 704/704 [==============================] - 3s 4ms/step - loss: 1.9149e-05 - mae: 0.0027 - val_loss: 3.6668e-05 - val_mae: 0.0039
# Epoch 191/1000
# 704/704 [==============================] - 3s 4ms/step - loss: 1.9066e-05 - mae: 0.0027 - val_loss: 3.3451e-05 - val_mae: 0.0034
# Epoch 192/1000
# 704/704 [==============================] - 3s 4ms/step - loss: 1.8948e-05 - mae: 0.0027 - val_loss: 3.7072e-05 - val_mae: 0.0038
# Epoch 193/1000
# 704/704 [==============================] - 3s 4ms/step - loss: 1.8814e-05 - mae: 0.0027 - val_loss: 3.3761e-05 - val_mae: 0.0035
# Epoch 194/1000
# 704/704 [==============================] - 3s 4ms/step - loss: 1.8869e-05 - mae: 0.0027 - val_loss: 3.4773e-05 - val_mae: 0.0038
# Epoch 195/1000
# 704/704 [==============================] - 3s 4ms/step - loss: 1.8760e-05 - mae: 0.0027 - val_loss: 3.3792e-05 - val_mae: 0.0035
# Epoch 196/1000
# 704/704 [==============================] - 3s 4ms/step - loss: 1.8842e-05 - mae: 0.0027 - val_loss: 3.4074e-05 - val_mae: 0.0036
# Epoch 197/1000
# 704/704 [==============================] - 3s 4ms/step - loss: 1.8890e-05 - mae: 0.0027 - val_loss: 3.6201e-05 - val_mae: 0.0038
# Epoch 198/1000
# 704/704 [==============================] - 3s 4ms/step - loss: 1.8825e-05 - mae: 0.0027 - val_loss: 3.6115e-05 - val_mae: 0.0039
# Epoch 199/1000
# 704/704 [==============================] - 3s 4ms/step - loss: 1.8858e-05 - mae: 0.0027 - val_loss: 3.3700e-05 - val_mae: 0.0035
# Epoch 200/1000
# 704/704 [==============================] - 3s 4ms/step - loss: 1.8752e-05 - mae: 0.0027 - val_loss: 3.3397e-05 - val_mae: 0.0034
# Epoch 201/1000
# 704/704 [==============================] - 3s 4ms/step - loss: 1.8778e-05 - mae: 0.0027 - val_loss: 4.2168e-05 - val_mae: 0.0045
# Epoch 202/1000
# 704/704 [==============================] - 3s 4ms/step - loss: 1.8715e-05 - mae: 0.0027 - val_loss: 3.8602e-05 - val_mae: 0.0039
# Epoch 203/1000
# 704/704 [==============================] - 3s 4ms/step - loss: 1.8834e-05 - mae: 0.0027 - val_loss: 3.4566e-05 - val_mae: 0.0038
# Epoch 204/1000
# 704/704 [==============================] - 3s 4ms/step - loss: 1.8655e-05 - mae: 0.0027 - val_loss: 3.5644e-05 - val_mae: 0.0038

# %%
# Learning Curves:
plot_history(history)
# Out:
# array([<AxesSubplot: title={'center': 'MSE'}, xlabel='Epoch', ylabel='Loss'>,
#        <AxesSubplot: title={'center': 'MAE'}, xlabel='Epoch', ylabel='MAE'>],
#       dtype=object)

# %%
#Baseline MAE
0.0048812746058099115
# Out:
# 0.0048812746058099115

# %%
model.evaluate(generator_val)
# Out:
# 175/175 [==============================] - 0s 1ms/step - loss: 3.0318e-05 - mae: 0.0032
# [3.0317864002427086e-05, 0.003189937910065055]

# %% [markdown]
# # Learning Curves viz code:

# %%
def plot_history(history):
    
    fig, ax = plt.subplots(1,2, figsize=(20,7))
    # Loss:MSE
    ax[0].plot(history.history['loss'])
    ax[0].plot(history.history['val_loss'])
    ax[0].set_title('MSE')
    ax[0].set_ylabel('Loss')
    ax[0].set_xlabel('Epoch')
    ax[0].legend(['Train', 'Validation'], loc='best')
    ax[0].grid(axis="x",linewidth=0.5)
    ax[0].grid(axis="y",linewidth=0.5)
    
    # Metrics:MAE
    
    ax[1].plot(history.history['mae'])
    ax[1].plot(history.history['val_mae'])
    ax[1].set_title('MAE')
    ax[1].set_ylabel('MAE')
    ax[1].set_xlabel('Epoch')
    ax[1].legend(['Train', 'Validation'], loc='best')
    ax[1].grid(axis="x",linewidth=0.5)
    ax[1].grid(axis="y",linewidth=0.5)
                        
    return ax
